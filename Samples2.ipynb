# %%
from edastatmil_milser import edas_tatmil as EDA
import pandas as pd

# %%
#Pequeña muestra de un catálogo SDSS

SDSS = pd.read_csv("/workspaces/Pre_ProyectoFinal/Samples/SDSS")

# %%
SDSS.head()
# Out:
#        _Glon      _Glat    _RAJ2000  _DEJ2000  mode q_mode  cl  \
# 0  96.273514 -60.185918  359.969883 -0.010228     1    NaN   6
# 1  96.297471 -60.177667  359.977512  0.002092     1      +   6
# 2  96.292509 -60.184247  359.977875 -0.004926     1    NaN   3
# 3  96.300504 -60.185279  359.981926 -0.004286     1      +   6
# 4  96.294664 -60.199210  359.984828 -0.018218     1    NaN   3
#
#                   SDSS  m_SDSS  R  ...  N  g(O)  r(E)  g(J)  r(F)  i(N)  \
# 0  J235952.77-000036.8     NaN  3  ...  0   NaN   NaN   NaN   NaN   NaN
# 1  J235954.60+000007.5     NaN  3  ...  0   NaN   NaN   NaN   NaN   NaN
# 2  J235954.69-000017.7     NaN  3  ...  0   NaN   NaN   NaN   NaN   NaN
# 3  J235955.66-000015.4     NaN  3  ...  6  19.6  18.2  19.5  18.4  18.0
# 4  J235956.35-000105.5     NaN  3  ...  0   NaN   NaN   NaN   NaN   NaN
#
#       RA_ICRS   DE_ICRS    ObsDate  Q
# 0  359.969883 -0.010228  2001.7887  3
# 1  359.977512  0.002092  2002.6785  2
# ...

# %%
EDA.explore(SDSS)
# Out:
# Rows: 61
# Columns: 134
# +-----------+----------------+------------+-----------+---------------+
# |           | Non-Null Count | Null Count | Data Type | Data Category |
# +-----------+----------------+------------+-----------+---------------+
# |   _Glon   |       61       |     0      |  float64  |   Numerical   |
# |   _Glat   |       61       |     0      |  float64  |   Numerical   |
# | _RAJ2000  |       61       |     0      |  float64  |   Numerical   |
# | _DEJ2000  |       61       |     0      |  float64  |   Numerical   |
# |   mode    |       61       |     0      |   int64   |   Numerical   |
# |  q_mode   |       10       |     51     |  object   |  Categorical  |
# |    cl     |       61       |     0      |   int64   |   Numerical   |
# |   SDSS    |       61       |     0      |  object   |  Categorical  |
# |  m_SDSS   |       0        |     61     |  float64  |   Numerical   |
# |     R     |       61       |     0      |   int64   |   Numerical   |
# ...

# %%
astro = pd.read_csv("/workspaces/Pre_ProyectoFinal/Samples/ZT-GDR3_Astro_example")

# %%
astro.head()
# Out:
#    u(G,C)_Interp_Table  RUWE_Table  RUWE_Maíz    _RAJ2000   _DEJ2000  recno  \
# 0             1.632618    0.926616   0.926777  222.329066 -43.194546   1127
# 1             1.509065    1.306133   1.305011  223.152969 -32.768964   1128
# 2             1.323960    1.143017   1.144556  211.839857 -44.970389   1129
# 3             1.151032    0.943147   0.942653  211.729730 -44.845841   1130
# 4             1.546904    0.919522   0.922038  211.728379 -44.839020   1131
#
#                 Source        GLON       GLAT     Plx  ...  b_AG-MSC_xa  \
# 0  6100369103963773056  324.690380  14.641657  7.8634  ...     0.061031
# 1  6205172593814395264  330.490237  23.538614  8.2556  ...     0.116510
# 2  6096979889428177024  316.771087  15.851534  8.0284  ...     0.000000
# 3  6096985150767974144  316.732597  15.993750  7.0894  ...     0.000000
# 4  6096985356926408320  316.733770  16.000546  7.0904  ...     0.238607
#
#    logpost-MSC  Accp-MSC  drift-MSC  Flag-MSC         NOAId   NOADist  \
# ...

# %%
EDA.explore(astro)
# Out:
# Rows: 999
# Columns: 256
# +---------------------+----------------+------------+-----------+---------------+
# |                     | Non-Null Count | Null Count | Data Type | Data Category |
# +---------------------+----------------+------------+-----------+---------------+
# | u(G,C)_Interp_Table |      999       |     0      |  float64  |   Numerical   |
# |     RUWE_Table      |      999       |     0      |  float64  |   Numerical   |
# |      RUWE_Maíz      |      999       |     0      |  float64  |   Numerical   |
# |      _RAJ2000       |      999       |     0      |  float64  |   Numerical   |
# |      _DEJ2000       |      999       |     0      |  float64  |   Numerical   |
# |        recno        |      999       |     0      |   int64   |   Numerical   |
# |       Source        |      999       |     0      |   int64   |   Numerical   |
# |        GLON         |      999       |     0      |  float64  |   Numerical   |
# ...
