# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tools import pm_analysis

# %%
keys = ['NGC1647', 'NGC2183', 'NGC1912', 'NGC2281', 'NGC2420', 'NGC2158', 'NGC2808', 'NGC6266', 'NGC2532', 'IC2395', 'NGC752', 'NGC2632', 'NGC2168', 'NGC884', 'NGC1851', 'NGC1904', 'NGC0104', 'M53', 'M67', 'M71', 'M92', 'NGC1245', 'NGC1798', 'NGC188', 'NGC0362', 'NGC5139', 'NGC3201', 'NGC5286', 'NGC5904']
dic={}

# %%
n = 28
k = 1.6
valid = pm_analysis(k, keys[n])
# Out:
# N_Stars: 419
# N_Valid: 371
# 88.54%

# %%
dic[keys[n]]=k

# %%
data_tuples = [(k, v) for k, v in dic.items()]
outlierstreatment_tati = pd.DataFrame(data_tuples, columns=['Cluster', 'k'])
outlierstreatment_tati.to_csv('../Samples/Auxiliar/OutTreatment_Silvia.csv')
