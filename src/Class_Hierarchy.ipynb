# %% [markdown]
# EJEMPLO: Hierarchical Clustering (Aglomerativo y Divisivo)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pickle import dump, load
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage


X_train = pd.read_csv('../Samples/Clean/Feature_Selection/X_train.csv')

# %%
# Crear el modelo de clustering aglomerativo
model = AgglomerativeClustering(n_clusters=None, distance_threshold=0)

X_train_array = X_train.to_numpy()

# Crear el linkage matrix
Z = linkage(X_train_array, method='ward')

# Graficar el dendrograma
plt.figure(figsize=(10, 7))
plt.title("Dendrograma del Clustering Aglomerativo")
dendrogram(Z)
plt.xlabel('Índice de la Muestra')
plt.ylabel('Distancia')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[2], line 7
#       4 X_train_array = X_train.to_numpy()
#       6 # Crear el linkage matrix
# ----> 7 Z = linkage(X_train_array, method='ward')
#       9 # Graficar el dendrograma
#      10 plt.figure(figsize=(10, 7))
#
# File c:\Users\Silvia\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\cluster\hierarchy.py:1024, in linkage(y, method, metric, optimal_ordering)
#    1018     if (y.shape[0] == y.shape[1] and np.allclose(np.diag(y), 0) and
#    1019             xp.all(y >= 0) and np.allclose(y, y.T)):
#    1020         warnings.warn('The symmetric non-negative hollow observation '
#    1021                       'matrix looks suspiciously like an uncondensed '
#    1022                       'distance matrix',
#    1023                       ClusterWarning, stacklevel=2)
# ...

# %% [markdown]
# El conjunto de datos es demasiado grande para la memoria disponible, de modo que no podemos correr este modelo con el dataset completo. A continuación, vamos a probar si es posible con un sample.

# %%
# Crear el modelo de clustering aglomerativo
model = AgglomerativeClustering(n_clusters=None, distance_threshold=0)

# Tomar una muestra del 50% de los datos
X_train_sampled = X_train.sample(frac=0.5, random_state=42)

# Convertir la muestra a un array NumPy
X_train_array_sampled = X_train_sampled.to_numpy()

# Ajustar el modelo al conjunto de datos
model.fit(X_train_array_sampled)

# Obtener los labels de los clústeres
labels = model.labels_

# Visualizar los resultados
plt.scatter(X_train_array_sampled[:, 0], X_train_array_sampled[:, 1], c=labels, cmap='rainbow', marker='o')
plt.title('Agglomerative Clustering on Sampled Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 11
#       8 X_train_array_sampled = X_train_sampled.to_numpy()
#      10 # Ajustar el modelo al conjunto de datos
# ---> 11 model.fit(X_train_array_sampled)
#      13 # Obtener los labels de los clústeres
#      14 labels = model.labels_
#
# File c:\Users\Silvia\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# ...

# %% [markdown]
# Un sample del 50% también requiere demasiada memoria y no es posible correr el modelo. Vamos a seguir probando con samples más pequeños.

# %%
# Crear el modelo de clustering aglomerativo
model = AgglomerativeClustering(n_clusters=None, distance_threshold=0)

# Tomar una muestra del 25% de los datos
X_train_sampled = X_train.sample(frac=0.25, random_state=42)

# Convertir la muestra a un array NumPy
X_train_array_sampled = X_train_sampled.to_numpy()

# Ajustar el modelo al conjunto de datos
model.fit(X_train_array_sampled)

# Obtener los labels de los clústeres
labels = model.labels_

# Visualizar los resultados
plt.scatter(X_train_array_sampled[:, 0], X_train_array_sampled[:, 1], c=labels, cmap='rainbow', marker='o')
plt.title('Agglomerative Clustering on Sampled Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 11
#       8 X_train_array_sampled = X_train_sampled.to_numpy()
#      10 # Ajustar el modelo al conjunto de datos
# ---> 11 model.fit(X_train_array_sampled)
#      13 # Obtener los labels de los clústeres
#      14 labels = model.labels_
#
# File c:\Users\Silvia\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# ...

# %% [markdown]
# Tampoco es posible correr el modelo con un 25% de los datos. Vamos a probar con un sample más pequeño.

# %%
# Crear el modelo de clustering aglomerativo
model = AgglomerativeClustering(n_clusters=None, distance_threshold=0)

# Tomar una muestra del 1% de los datos
X_train_sampled = X_train.sample(frac=0.01, random_state=42)

# Convertir la muestra a un array NumPy
X_train_array_sampled = X_train_sampled.to_numpy()

# Ajustar el modelo al conjunto de datos
model.fit(X_train_array_sampled)

# Obtener los labels de los clústeres
labels = model.labels_

# Visualizar los resultados
plt.figure(figsize=(12, 8))
plt.scatter(X_train_array_sampled[:, 0], X_train_array_sampled[:, 1], c=labels, cmap='rainbow', marker='o')
plt.title('Agglomerative Clustering on Sampled Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# Ha sido posible correr el modelo con una muestra del 1% de los datos, vamos a intentarlo con un sample más grande, a ver hasta dónde podemos llegar.

# %%
# Crear el modelo de clustering aglomerativo
model = AgglomerativeClustering(n_clusters=None, distance_threshold=0)

# Tomar una muestra del 5% de los datos
X_train_sampled = X_train.sample(frac=0.05, random_state=42)

# Convertir la muestra a un array NumPy
X_train_array_sampled = X_train_sampled.to_numpy()

# Ajustar el modelo al conjunto de datos
model.fit(X_train_array_sampled)

# Obtener los labels de los clústeres
labels = model.labels_

# Visualizar los resultados
plt.figure(figsize=(12, 8))
plt.scatter(X_train_array_sampled[:, 0], X_train_array_sampled[:, 1], c=labels, cmap='rainbow', marker='o')
plt.title('Agglomerative Clustering on Sampled Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
#Guardamos el modelo, aunque solo ha sido posible utilizar un sample del 5% de los datos.
dump(model, open("../Models/agglomerativeclustering.pkl", "wb"))

# %% [markdown]
# Ha sido posible correr el modelo con un sample del 5% de los datos. Pero lo vamos a dejar aquí con este modelo porque no queremos renunciar a una parte tan grande de los datos para entrenar el modelo si con otro modelo de clusering tenemos la posibilidad de usar todos los datos y obtener buenos resultados.
